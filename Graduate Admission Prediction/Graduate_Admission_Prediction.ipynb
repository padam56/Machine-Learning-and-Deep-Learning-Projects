# %% [markdown]
# # 1. UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. IMPORT LIBRARIES AND DATASET

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)

# %%
# read the csv file 
admission_df = pd.read_csv('Admission_Predict.csv')

# %%
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
# Let's drop the serial no.
admission_df.drop('Serial No.', axis = 1, inplace = True) 
admission_df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %% [markdown]
# # 3. PERFORM EXPLORATORY DATA ANALYSIS

# %%
# checking the null values
admission_df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Check the dataframe information
admission_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          500 non-null    int64
#  1   TOEFL Score        500 non-null    int64
#  2   University Rating  500 non-null    int64
#  3   SOP                500 non-null    float64
#  4   LOR                500 non-null    float64
#  5   CGPA               500 non-null    float64
#  6   Research           500 non-null    int64
#  7   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 31.4 KB

# %%
# Statistical summary of the dataframe
admission_df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# 50%      8.560000    1.000000          0.72000
# 75%      9.040000    1.000000          0.82000
# max      9.920000    1.000000          0.97000

# %%
# Grouping by University ranking 
df_university = admission_df.groupby(by='University Rating').mean()
df_university
# Out:
#                     GRE Score  TOEFL Score       SOP      LOR       CGPA  \
# University Rating
# 1                  304.911765   100.205882  1.941176  2.426471  7.798529
# 2                  309.134921   103.444444  2.682540  2.956349  8.177778
# 3                  315.030864   106.314815  3.308642  3.401235  8.500123
# 4                  323.304762   110.961905  4.000000  3.947619  8.936667
# 5                  327.890411   113.438356  4.479452  4.404110  9.278082
#
#                    Research  Chance of Admit
# University Rating
# 1                  0.294118         0.562059
# 2                  0.293651         0.626111
# 3                  0.537037         0.702901
# 4                  0.780952         0.801619
# 5                  0.876712         0.888082

# %% [markdown]
# # 4. PERFORM DATA VISUALIZATION

# %%
admission_df.hist(bins = 30, figsize = (20,20), color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'GRE Score'}>,
#         <AxesSubplot:title={'center':'TOEFL Score'}>,
#         <AxesSubplot:title={'center':'University Rating'}>],
#        [<AxesSubplot:title={'center':'SOP'}>,
#         <AxesSubplot:title={'center':'LOR '}>,
#         <AxesSubplot:title={'center':'CGPA'}>],
#        [<AxesSubplot:title={'center':'Research'}>,
#         <AxesSubplot:title={'center':'Chance of Admit'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.pairplot(admission_df)

# %%
for i in admission_df.columns:
  sns.scatterplot(x = i, y='Chance of Admit', hue = "University Rating", hue_norm=(1,5),data= admission_df)
  plt.show()

# %%
corr_matrix = admission_df.corr()
corr_matrix
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.827200           0.635376  0.613498
# TOEFL Score         0.827200     1.000000           0.649799  0.644410
# University Rating   0.635376     0.649799           1.000000  0.728024
# SOP                 0.613498     0.644410           0.728024  1.000000
# LOR                 0.524679     0.541563           0.608651  0.663707
# CGPA                0.825878     0.810574           0.705254  0.712154
# Research            0.563398     0.467012           0.427047  0.408116
# Chance of Admit     0.810351     0.792228           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.524679  0.825878  0.563398         0.810351
# TOEFL Score        0.541563  0.810574  0.467012         0.792228
# University Rating  0.608651  0.705254  0.427047         0.690132
# SOP                0.663707  0.712154  0.408116         0.684137
# LOR                1.000000  0.637469  0.372526         0.645365
# CGPA               0.637469  1.000000  0.501311         0.882413
# Research           0.372526  0.501311  1.000000         0.545871
# Chance of Admit    0.645365  0.882413  0.545871         1.000000

# %%
plt.figure(figsize = (12,12))
sns.heatmap(corr_matrix, annot = True)
plt.show()
# From the correlation matrix, it can be seen that, all parameters have positive correlation with chance of getting admission in to the university.

# %% [markdown]
# # 5. CREATE TRAINING AND TESTING DATASET

# %%
admission_df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
X = admission_df.drop(columns = ['Chance of Admit'])

# %%
y = admission_df['Chance of Admit']

# %%
X.shape
# Out:
# (500, 7)

# %%
y.shape
# Out:
# (500,)

# %%
X = np.array(X)
y = np.array(y)

# %%
# reshaping the array from (500,) to (500, 1)
y = y.reshape(-1,1)
y.shape
# Out:
# (500, 1)

# %%
# scaling the data before training the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
# spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15)

# %% [markdown]
# # 6. TRAIN AND EVALUATE A LINEAR REGRESSION MODEL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

LinearRegression_model = LinearRegression()
LinearRegression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
accuracy_LinearRegression = LinearRegression_model.score(X_test, y_test)
accuracy_LinearRegression
# Out:
# 0.8069213927879832

# %% [markdown]
# # 7. TRAIN AND EVALUATE AN ARTIFICIAL NEURAL NETWORK

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install --upgrade --ignore-installed tensorflow-gpu==1.3.1


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam


optimizer = Adam()
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 7))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==1.3.1
# ERROR: No matching distribution found for tensorflow-gpu==1.3.1
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                400
# _________________________________________________________________
# activation (Activation)      (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               7650
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               22650
# _________________________________________________________________
# activation_2 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                7550
# _________________________________________________________________
# activation_3 (Activation)    (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 38,301
# Trainable params: 38,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')

# %%
epochs_hist = ANN_model.fit(X_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 1s 18ms/step - loss: 0.6135 - val_loss: 0.1788
# Epoch 2/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3223 - val_loss: 0.1844
# Epoch 3/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2985 - val_loss: 0.1519
# Epoch 4/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3079 - val_loss: 0.1581
# Epoch 5/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2968 - val_loss: 0.1609
# Epoch 6/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2955 - val_loss: 0.1617
# Epoch 7/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2584 - val_loss: 0.1648
# Epoch 8/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2624 - val_loss: 0.1419
# Epoch 9/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2387 - val_loss: 0.1467
# Epoch 10/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2503 - val_loss: 0.1577
# Epoch 11/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2128 - val_loss: 0.1466
# Epoch 12/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2578 - val_loss: 0.1438
# Epoch 13/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2481 - val_loss: 0.1581
# Epoch 14/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2270 - val_loss: 0.1474
# Epoch 15/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2602 - val_loss: 0.1528
# Epoch 16/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2291 - val_loss: 0.1474
# Epoch 17/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1959 - val_loss: 0.1347
# Epoch 18/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2264 - val_loss: 0.1595
# Epoch 19/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2420 - val_loss: 0.1635
# Epoch 20/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2257 - val_loss: 0.1464
# Epoch 21/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2119 - val_loss: 0.1407
# Epoch 22/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2135 - val_loss: 0.1391
# Epoch 23/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2193 - val_loss: 0.1360
# Epoch 24/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1946 - val_loss: 0.1486
# Epoch 25/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2080 - val_loss: 0.1430
# Epoch 26/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2120 - val_loss: 0.1365
# Epoch 27/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2037 - val_loss: 0.1447
# Epoch 28/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2163 - val_loss: 0.1479
# Epoch 29/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2048 - val_loss: 0.1292
# Epoch 30/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2002 - val_loss: 0.1385
# Epoch 31/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1803 - val_loss: 0.1311
# Epoch 32/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1995 - val_loss: 0.1450
# Epoch 33/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2185 - val_loss: 0.1596
# Epoch 34/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1972 - val_loss: 0.1274
# Epoch 35/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2040 - val_loss: 0.1353
# Epoch 36/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2052 - val_loss: 0.1316
# Epoch 37/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1934 - val_loss: 0.1276
# Epoch 38/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1787 - val_loss: 0.1579
# Epoch 39/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1960 - val_loss: 0.1264
# Epoch 40/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1868 - val_loss: 0.1315
# Epoch 41/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1903 - val_loss: 0.1433
# Epoch 42/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1751 - val_loss: 0.1346
# Epoch 43/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1749 - val_loss: 0.1311
# Epoch 44/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2061 - val_loss: 0.1296
# Epoch 45/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1765 - val_loss: 0.1282
# Epoch 46/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1734 - val_loss: 0.1333
# Epoch 47/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1595 - val_loss: 0.1234
# Epoch 48/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1731 - val_loss: 0.1244
# Epoch 49/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1563 - val_loss: 0.1226
# Epoch 50/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1578 - val_loss: 0.1276
# Epoch 51/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1804 - val_loss: 0.1503
# Epoch 52/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1616 - val_loss: 0.1427
# Epoch 53/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1673 - val_loss: 0.1267
# Epoch 54/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1606 - val_loss: 0.1465
# Epoch 55/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1730 - val_loss: 0.1421
# Epoch 56/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2016 - val_loss: 0.1380
# Epoch 57/100
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1667 - val_loss: 0.1490
# Epoch 58/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1596 - val_loss: 0.1314
# Epoch 59/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1617 - val_loss: 0.1267
# Epoch 60/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1569 - val_loss: 0.1448
# Epoch 61/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1556 - val_loss: 0.1299
# Epoch 62/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1551 - val_loss: 0.1277
# Epoch 63/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1669 - val_loss: 0.1614
# Epoch 64/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1702 - val_loss: 0.1304
# Epoch 65/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1645 - val_loss: 0.1500
# Epoch 66/100
# 17/17 [==============================] - ETA: 0s - loss: 0.183 - 0s 3ms/step - loss: 0.1587 - val_loss: 0.1309
# Epoch 67/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1571 - val_loss: 0.1403
# Epoch 68/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1529 - val_loss: 0.1700
# Epoch 69/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1438 - val_loss: 0.1368
# Epoch 70/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1458 - val_loss: 0.1369
# Epoch 71/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1578 - val_loss: 0.1397
# Epoch 72/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1581 - val_loss: 0.1673
# Epoch 73/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1810 - val_loss: 0.1507
# Epoch 74/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1675 - val_loss: 0.1226
# Epoch 75/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1494 - val_loss: 0.1333
# Epoch 76/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1450 - val_loss: 0.1223
# Epoch 77/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1478 - val_loss: 0.1348
# Epoch 78/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1358 - val_loss: 0.1383
# Epoch 79/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1360 - val_loss: 0.1540
# Epoch 80/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1569 - val_loss: 0.1304
# Epoch 81/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1299 - val_loss: 0.1398
# Epoch 82/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1401 - val_loss: 0.1365
# Epoch 83/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1389 - val_loss: 0.1336
# Epoch 84/100
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1416 - val_loss: 0.1310
# Epoch 85/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1339 - val_loss: 0.1520
# Epoch 86/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1386 - val_loss: 0.1310
# Epoch 87/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1224 - val_loss: 0.1438
# Epoch 88/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1273 - val_loss: 0.1388
# Epoch 89/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1328 - val_loss: 0.1320
# Epoch 90/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1280 - val_loss: 0.1326
# Epoch 91/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1373 - val_loss: 0.1392
# Epoch 92/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1359 - val_loss: 0.1297
# Epoch 93/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1354 - val_loss: 0.1355
# Epoch 94/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1267 - val_loss: 0.1404
# Epoch 95/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1127 - val_loss: 0.1387
# Epoch 96/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1157 - val_loss: 0.1263
# Epoch 97/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1121 - val_loss: 0.1297
# Epoch 98/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1264 - val_loss: 0.1375
# Epoch 99/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1460 - val_loss: 0.1301
# Epoch 100/100
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1261 - val_loss: 0.1454

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2456
# Accuracy : 0.7543632239103317

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %% [markdown]
# # 8. TRAIN AND EVALUATE A DECISION TREE AND RANDOM FOREST MODELS

# %%
# Decision tree builds regression or classification models in the form of a tree structure. 
# Decision tree breaks down a dataset into smaller subsets while at the same time an associated decision tree is incrementally developed. 
# The final result is a tree with decision nodes and leaf nodes.
# Great resource: https://www.saedsayad.com/decision_tree_reg.htm

from sklearn.tree import DecisionTreeRegressor

DecisionTree_model = DecisionTreeRegressor()
DecisionTree_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
accuracy_DecisionTree = DecisionTree_model.score(X_test, y_test)
accuracy_DecisionTree
# Out:
# 0.41882683798662756

# %%
# Many decision Trees make up a random forest model which is an ensemble model. 
# Predictions made by each decision tree are averaged to get the prediction of random forest model.
# A random forest regressor fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. 

from sklearn.ensemble import RandomForestRegressor

RandomForest_model = RandomForestRegressor(n_estimators=100, max_depth=10)
RandomForest_model.fit(X_train, y_train)
# Out:
# <ipython-input-33-224fa8342568>:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RandomForest_model.fit(X_train, y_train)
# RandomForestRegressor(max_depth=10)

# %%
accuracy_RandomForest = RandomForest_model.score(X_test, y_test)
accuracy_RandomForest
# Out:
# 0.7278630193205917

# %% [markdown]
# # 9. UNDERSTAND VARIOUS REGRESSION KPIs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10. PRINT KPIs FOR THE BEST MODEL

# %%
y_predict = LinearRegression_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 75

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.057
# MSE = 0.003278368342694292
# MAE = 0.040985588663634026
# R2 = 0.8069213927879832
# Adjusted R2 = 0.7867490009897129
